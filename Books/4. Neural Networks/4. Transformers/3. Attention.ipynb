# %% [markdown]
# # 1. Geral Attention
#
# Attention it's the algorithm that run the most famous LLMs nowadays, like ChatGPT, Claude, Gemini and a lot of more. In this section we gonna analyze and review the attention algorithm and their types

# %%
import torch
import torch.nn
import torch.nn.functional as F

# %%
x = torch.rand(2, 5)
# Simulation the matrix data with the embedding alredy redy
# 2 tokens, 5 dimensions of embedding

print(f'Data matrix (input):\n{x}')
# Out:
# Data matrix (input):
# tensor([[0.9694, 0.6370, 0.2854, 0.9179, 0.3443],
#         [0.3305, 0.5212, 0.0126, 0.6272, 0.5953]])

# %% [markdown]
# ## 1.1 QKV

# %% [markdown]
# ## 1.2 Scores

# %% [markdown]
# # 2. Types

# %% [markdown]
# ## 2.1 Self-Attention
# **All the tokens have the scores for others tokens**

# %% [markdown]
# ## 2.2 Masked-Attention
# **The tokens only have access to past tokens**

# %% [markdown]
# ## 2.3 Cross-Attention

# %% [markdown]
# ## 2.4 Flash-Attention

# %% [markdown]
# ## 2.5 Multi-Query-Attention (MQA)

# %% [markdown]
# ## 2.6 Group-Query-Attention (GQA)

# %% [markdown]
# ## 2.7 Rotatory-Attention (RoPE)
