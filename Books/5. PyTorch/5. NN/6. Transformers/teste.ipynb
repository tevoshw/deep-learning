# %%
import torch.nn as nn

decoder_block = nn.TransformerDecoderLayer(d_model=10, batch_first=True, nhead=1, dropout=0.2, bias= False, dim_feedforward=10)
decoder = nn.TransformerDecoder(decoder_layer=decoder_block, num_layers=10)

encoder_block = nn.TransformerEncoderLayer(d_model=10, batch_first=True, nhead=1, dropout=0.2, bias= False, dim_feedforward=10)
encoder = nn.TransformerEncoder(encoder_layer=encoder_block, num_layers=10)

transformers = nn.Transformer(d_model=10, batch_first=True, nhead=1, dropout=0.2, bias= False, dim_feedforward=10 )


mha = nn.MultiheadAttention(embed_dim=10)


mask = nn.Transformer.generate_square_subsequent_mask(seq_len)
