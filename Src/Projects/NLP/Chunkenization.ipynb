# %% [markdown]
# # 1. Truncation
#
#
#         Usuário manda mensagem
#                 │
#                 ▼
#         LangChain junta: [system] + [histórico] + [nova mensagem]
#                 │
#                 ▼
#         Conta os tokens do total
#                 │
#                 ├── cabe? → manda pra API
#                 │
#                 └── não cabe? → dropa turnos antigos até caber
#                         │
#                         ▼
#                     manda pra API

# %%
from langchain.memory import ConversationTokenBufferMemory


memory = ConversationTokenBufferMemory(
    llm=llm,              # usa o llm só pra contar tokens
    max_token_limit=4000, # limite do histórico
    return_messages=True,
    memory_key="chat_history",
)

# %% [markdown]
# # 2. Summarization

# %% [markdown]
# # 3. RAG

# %% [markdown]
# # 4. Memory Extern

# %% [markdown]
# # 5. Full Context
